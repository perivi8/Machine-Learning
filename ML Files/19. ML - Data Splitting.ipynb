# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("D:\\ML\\19. ML - Details.xlsx")
df
# Out:
#     rollno  enroll ment  class    ratio    mobile no  Team  pincode
# 0        1    206320014      7  01:03:00  8106811285    DC   524126
# 1        2    206320015      7  01:05:00  9440203095    MI   524127
# 2        3    206320016      7  01:07:00  4194560490  PBKS   524128
# 3        4    206320017      7  01:09:00  6441761165   CSK   524129
# 4        5    206320018      7  01:11:00  6461496845    RR   524130
# 5        6    206320019      7  01:13:00  6552665965   SRH   524131
# 6        7    206320020      7  01:15:00  5784889566   LSG   524132
# 7        8    206320021      7  01:17:00  6589963588    GT   524133
# 8        9    206320022      7  01:19:00  6646663556   RCB   524134
# 9       10    206320023      7  01:21:00  6566781661   KKR   524135
# 10      11    206320024      7  01:23:00  6664679932    DC   524136
# 11      12    206320025      7  01:25:00  6554147869    MI   524137
# 12      13    206320026      7  01:27:00  8846862461  PBKS   524138
# ...

# %%
a = df.drop('class' , axis = 1)
a
# Out:
#     rollno  enroll ment    ratio    mobile no  Team  pincode
# 0        1    206320014  01:03:00  8106811285    DC   524126
# 1        2    206320015  01:05:00  9440203095    MI   524127
# 2        3    206320016  01:07:00  4194560490  PBKS   524128
# 3        4    206320017  01:09:00  6441761165   CSK   524129
# 4        5    206320018  01:11:00  6461496845    RR   524130
# 5        6    206320019  01:13:00  6552665965   SRH   524131
# 6        7    206320020  01:15:00  5784889566   LSG   524132
# 7        8    206320021  01:17:00  6589963588    GT   524133
# 8        9    206320022  01:19:00  6646663556   RCB   524134
# 9       10    206320023  01:21:00  6566781661   KKR   524135
# 10      11    206320024  01:23:00  6664679932    DC   524136
# 11      12    206320025  01:25:00  6554147869    MI   524137
# 12      13    206320026  01:27:00  8846862461  PBKS   524138
# 13      14    206320027  01:29:00  2534264899   CSK   524139
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['Team'] , df['pincode'])

# %% [markdown]
# # Train_Test_split

# %%
from sklearn.model_selection import train_test_split

# %%
X = a[['rollno', 'enroll ment']]
X

# or 

X = a.drop(a.columns[[2 ,3 , 4 ,5]] , axis=1)
X
# Out:
#     rollno  enroll ment
# 0        1    206320014
# 1        2    206320015
# 2        3    206320016
# 3        4    206320017
# 4        5    206320018
# 5        6    206320019
# 6        7    206320020
# 7        8    206320021
# 8        9    206320022
# 9       10    206320023
# 10      11    206320024
# 11      12    206320025
# 12      13    206320026
# 13      14    206320027
# 14      15    206320028
# 15      16    206320029
# 16      17    206320030
# 17      18    206320031
# 18      19    206320032
# 19      20    206320033

# %%
Y = a['pincode']
Y

# or

# Y = df.iloc[: , -1]
# Y
# Out:
# 0     524126
# 1     524127
# 2     524128
# 3     524129
# 4     524130
# 5     524131
# 6     524132
# 7     524133
# 8     524134
# 9     524135
# 10    524136
# 11    524137
# 12    524138
# 13    524139
# 14    524140
# 15    524141
# 16    524142
# 17    524143
# 18    524144
# 19    524145
# Name: pincode, dtype: int64

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X,Y,test_size= 0.2, random_state=0 )

# %%
X_train
# Out:
#     rollno  enroll ment
# 10      11    206320024
# 17      18    206320031
# 6        7    206320020
# 13      14    206320027
# 4        5    206320018
# 2        3    206320016
# 5        6    206320019
# 14      15    206320028
# 9       10    206320023
# 7        8    206320021
# 16      17    206320030
# 11      12    206320025
# 3        4    206320017
# 0        1    206320014
# 15      16    206320029
# 12      13    206320026

# %%
X_test
# Out:
#     rollno  enroll ment
# 18      19    206320032
# 1        2    206320015
# 19      20    206320033
# 8        9    206320022

# %%
Y_train
# Out:
# 10    524136
# 17    524143
# 6     524132
# 13    524139
# 4     524130
# 2     524128
# 5     524131
# 14    524140
# 9     524135
# 7     524133
# 16    524142
# 11    524137
# 3     524129
# 0     524126
# 15    524141
# 12    524138
# Name: pincode, dtype: int64

# %%
Y_test
# Out:
# 18    524144
# 1     524127
# 19    524145
# 8     524134
# Name: pincode, dtype: int64

# %% [markdown]
# # Linear Regression

# %%
## This is Multiple linear regression

# %%
from sklearn.linear_model import LinearRegression
z = LinearRegression()

# %%
z.fit(X_train , Y_train)
# Out:
# LinearRegression()

# %%
prediction = z.predict(X_train )   # this is equal to the Y_train
print(prediction)

# If we use X_train for predict means , then use plt.scatter(Y_train , predection)   --- For Multiple Linear Regression
# If we use X_test for predict means , then use plt.scatter(Y_test , predection)    --- For Multiple Linear Regression
# Out:
# [524136. 524143. 524132. 524139. 524130. 524128. 524131. 524140. 524135.
#  524133. 524142. 524137. 524129. 524126. 524141. 524138.]

# %%
# z.predict(Y_test)   # no need to write like this , just write Y_test

# %%
X_test            # this is also same
# Out:
#     rollno  enroll ment
# 18      19    206320032
# 1        2    206320015
# 19      20    206320033
# 8        9    206320022

# %%
Y_test
# Out:
# 18    524144
# 1     524127
# 19    524145
# 8     524134
# Name: pincode, dtype: int64

# %%
X_train
# Out:
#     rollno  enroll ment
# 10      11    206320024
# 17      18    206320031
# 6        7    206320020
# 13      14    206320027
# 4        5    206320018
# 2        3    206320016
# 5        6    206320019
# 14      15    206320028
# 9       10    206320023
# 7        8    206320021
# 16      17    206320030
# 11      12    206320025
# 3        4    206320017
# 0        1    206320014
# 15      16    206320029
# 12      13    206320026

# %%
Y_train
# Out:
# 10    524136
# 17    524143
# 6     524132
# 13    524139
# 4     524130
# 2     524128
# 5     524131
# 14    524140
# 9     524135
# 7     524133
# 16    524142
# 11    524137
# 3     524129
# 0     524126
# 15    524141
# 12    524138
# Name: pincode, dtype: int64

# %%
z.score(X_test , Y_test)    # score is used the accuracy in between the X_test and Y_test
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(Y_train , prediction) 
plt.plot([Y_train.min(),Y_train.max()] ,[Y_train.min(),Y_train.max()] , 'k--' )   # This is use only for Multple linear regression for Plot line..

plt.show()
